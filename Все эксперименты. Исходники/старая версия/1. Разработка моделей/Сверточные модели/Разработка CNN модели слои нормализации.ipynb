# %% [markdown]
# # Imports

# %%
#Data loading
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.metrics import roc_auc_score, f1_score
from IPython.display import clear_output

from joblib import load
from tqdm import trange
from tqdm.notebook import tqdm



from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import StratifiedKFold


# GNN Model
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import GCNConv, GraphConv, GATConv, GATv2Conv, SAGEConv


# Sparse vector
from Sparse_vector.sparse_vector import SparseVector

# %%
def set_random_seed(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# %% [markdown]
# # Data loading

# %%
chrom_names = [f'chr{i}' for i in list(range(1, 23)) + ['X', 'Y','M']]
features = [i[:-4] for i in os.listdir('z_dna/hg38_features/sparse/') if i.endswith('.pkl')]
groups = ['DNase-seq', 'Histone', 'RNA polymerase', 'TFs and others']
feature_names = [i for i in features]

# %%
def chrom_reader(chrom):
    files = sorted([i for i in os.listdir(f'z_dna/hg38_dna/') if f"{chrom}_" in i])
    return ''.join([load(f"z_dna/hg38_dna/{file}") for file in files])

# %%
# %%time
DNA = {chrom:chrom_reader(chrom) for chrom in tqdm(chrom_names)}
#ZDNA = load('z_dna/hg38_zdna/sparse/ZDNA_shin.pkl')
ZDNA = load('z_dna/hg38_zdna/sparse/ZDNA_cousine.pkl')

#ZDNA = load('z_dna/hg38_zdna/sparse/ZDNA_cousine.pkl')

DNA_features = {feature: load(f'z_dna/hg38_features/sparse/{feature}.pkl')
                for feature in tqdm(feature_names)}
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/1946 [00:00<?, ?it/s]
# CPU times: user 2min 13s, sys: 4.84 s, total: 2min 18s
# Wall time: 2min 17s

# %%
pd.DataFrame(data={'feature':feature_names}).to_csv('features.csv')

# %%
feature_names
# Out:
# ['TFs_and_others_ING2',
#  'TFs_and_others_ARID5B',
#  'TFs_and_others_PKM',
#  'TFs_and_others_HMG20B',
#  'TFs_and_others_GTF2I',
#  'TFs_and_others_BRF1',
#  'TFs_and_others_ZNF785',
#  'TFs_and_others_CTCFL',
#  'TFs_and_others_ZNF576',
#  'TFs_and_others_FXR2',
#  'TFs_and_others_HHV UL87',
#  'TFs_and_others_PRMT3',
#  'TFs_and_others_RLF',
#  'TFs_and_others_POU2F1',
#  'TFs_and_others_CEBPA',
#  'TFs_and_others_HES2',
#  'TFs_and_others_PAX5',
#  'TFs_and_others_MAP2K1',
#  'TFs_and_others_TEAD2',
#  'TFs_and_others_CERS6',
#  'TFs_and_others_ARID4B',
#  'TFs_and_others_TAF2',
#  'TFs_and_others_HIV Tat',
#  'TFs_and_others_ZNF425',
#  'TFs_and_others_ATF4',
#  'TFs_and_others_DOT1L',
#  'TFs_and_others_ZNF311',
#  'TFs_and_others_SOX1',
#  'Histone_H3R26cit',
#  'TFs_and_others_ZNF274',
#  'TFs_and_others_USP7',
#  'Histone_H3K79me3',
#  'TFs_and_others_IKZF3',
#  'TFs_and_others_AGO2',
#  'TFs_and_others_DONSON',
#  'TFs_and_others_HOXD11',
#  'TFs_and_others_TSC22D2',
#  'TFs_and_others_ZNF251',
#  'Histone_H3S28ph',
#  'TFs_and_others_ONECUT2',
#  'Histone_H4K20me1',
#  'TFs_and_others_ZC3H4',
#  'TFs_and_others_PSMD1',
#  'TFs_and_others_ZSCAN16',
#  'TFs_and_others_NUFIP1',
#  'TFs_and_others_KLF5',
#  'TFs_and_others_RBM22',
#  'TFs_and_others_SUPT6H',
#  'TFs_and_others_FOXJ3',
#  'TFs_and_others_FBXO44',
#  'TFs_and_others_RFXANK',
#  'TFs_and_others_ZSCAN12',
#  'TFs_and_others_NFIL3',
#  'TFs_and_others_PLRG1',
#  'TFs_and_others_SRSF1',
#  'TFs_and_others_GTF2F2',
#  'TFs_and_others_ZNF189',
#  'TFs_and_others_SP110',
#  'TFs_and_others_PRDM10',
#  'TFs_and_others_WDHD1',
#  'TFs_and_others_ETS2',
#  'TFs_and_others_INTS5',
#  'TFs_and_others_MLLT6',
#  'TFs_and_others_PHIP',
#  'TFs_and_others_ZKSCAN8',
#  'TFs_and_others_ZNF816',
#  'TFs_and_others_BCL10',
#  'TFs_and_others_RORB',
#  'TFs_and_others_ZFP36L2',
#  'TFs_and_others_CCAR2',
#  'TFs_and_others_GATA6',
#  'TFs_and_others_PAXIP1',
#  'TFs_and_others_NKX6-1',
#  'TFs_and_others_SAP30',
#  'TFs_and_others_ZNF225',
#  'TFs_and_others_RUNX2',
#  'TFs_and_others_TEAD3',
#  'TFs_and_others_NFXL1',
#  'TFs_and_others_ALYREF',
#  'TFs_and_others_KLF14',
#  'TFs_and_others_PAX8',
#  'RNA_polymerase_RNA polymerase II',
#  'Histone_H2AK9ac',
#  'TFs_and_others_HHEX',
#  'TFs_and_others_ZNF654',
#  'TFs_and_others_CCNT1',
#  'TFs_and_others_SFPQ',
#  'TFs_and_others_NFKB1',
#  'TFs_and_others_ZNF451',
#  'TFs_and_others_ZNF579',
#  'TFs_and_others_TET3',
#  'TFs_and_others_GPN1',
#  'TFs_and_others_DNA2',
#  'TFs_and_others_BRD2',
#  'TFs_and_others_NCOR1',
#  'TFs_and_others_ZNF556',
#  'TFs_and_others_POU3F2',
#  'TFs_and_others_SOX3',
#  'TFs_and_others_ARID3B',
#  'TFs_and_others_TFEB',
#  'TFs_and_others_ZC3H8',
#  'TFs_and_others_SMAD3',
#  'TFs_and_others_NR2F1',
#  'TFs_and_others_FOS',
#  'TFs_and_others_CDX4',
#  'TFs_and_others_MKL1',
#  'TFs_and_others_NKX2-2',
#  'Histone_H2A.ZK4K7K11ac',
#  'Histone_H4K5K8K12ac',
#  'TFs_and_others_ZC3H11A',
#  'TFs_and_others_GTF2E2',
#  'TFs_and_others_BCL6',
#  'TFs_and_others_PDHA1',
#  'TFs_and_others_CHD6',
#  'Histone_H3K122sc',
#  'TFs_and_others_CHD8',
#  'TFs_and_others_MIER2',
#  'TFs_and_others_PHF19',
#  'TFs_and_others_U2AF2',
#  'TFs_and_others_TIGD3',
#  'TFs_and_others_SNAPC5',
#  'TFs_and_others_POU6F1',
#  'TFs_and_others_ISX',
#  'TFs_and_others_RAD21',
#  'TFs_and_others_PHF10',
#  'TFs_and_others_ZNF302',
#  'TFs_and_others_STAT6',
#  'TFs_and_others_NONO',
#  'TFs_and_others_CPSF7',
#  'Histone_H3K79suc',
#  'TFs_and_others_HNF4A',
#  'TFs_and_others_NR2C1',
#  'TFs_and_others_ZNF232',
#  'TFs_and_others_GTF3A',
#  'TFs_and_others_KHSRP',
#  'Histone_H3K28ac',
#  'TFs_and_others_MED7',
#  'TFs_and_others_PRKDC',
#  'RNA_polymerase_POLR3C',
#  'TFs_and_others_E2F5',
#  'TFs_and_others_SON',
#  'Histone_H1B',
#  'TFs_and_others_HES5',
#  'TFs_and_others_KDM2A',
#  'TFs_and_others_BRCA1',
#  'TFs_and_others_CSDC2',
#  'TFs_and_others_ZNF549',
#  'TFs_and_others_NHLH1',
#  'TFs_and_others_DCP2',
#  'TFs_and_others_RBM34',
#  'TFs_and_others_NCAPH2',
#  'TFs_and_others_PHF13',
#  'TFs_and_others_SCRT1',
#  'TFs_and_others_MORC2',
#  'Histone_H3K4me2',
#  'Histone_H4R3me2',
#  'Histone_H3K4me1',
#  'TFs_and_others_RBBP4',
#  'TFs_and_others_ZNF34',
#  'TFs_and_others_ZNF518A',
#  'Histone_H4K8ac',
#  'TFs_and_others_ZNF551',
#  'TFs_and_others_ZNF552',
#  'TFs_and_others_STAG2',
#  'Histone_H3K9me2',
#  'TFs_and_others_FOSL2',
#  'TFs_and_others_RNF2',
#  'TFs_and_others_Hepatitis B Virus X antigen',
#  'TFs_and_others_TFDP2',
#  'TFs_and_others_TCF12',
#  'TFs_and_others_ZEB2',
#  'TFs_and_others_ZNF76',
#  'TFs_and_others_ZNF280B',
#  'Histone_H4K20me3',
#  'TFs_and_others_ZNF561',
#  'TFs_and_others_ZNF277',
#  'TFs_and_others_ZNF395',
#  'TFs_and_others_ZNF645',
#  'TFs_and_others_RING1',
#  'TFs_and_others_NCBP1',
#  'TFs_and_others_ZNF550',
#  'TFs_and_others_ZNF423',
#  'TFs_and_others_ADNP2',
#  'TFs_and_others_TBX21',
#  'TFs_and_others_ZNF770',
#  'TFs_and_others_ERH',
#  'TFs_and_others_WRN',
#  'TFs_and_others_JRK',
#  'TFs_and_others_SLBP',
#  'TFs_and_others_SP5',
#  'TFs_and_others_FUBP3',
#  'TFs_and_others_CRTC2',
#  'TFs_and_others_SETX',
#  'Histone_H2A.X',
#  'TFs_and_others_IKZF2',
#  'TFs_and_others_ARID3A',
#  'TFs_and_others_DDX5',
#  'TFs_and_others_RBM25',
#  'TFs_and_others_INTS10',
#  'TFs_and_others_PPARA',
#  'TFs_and_others_HDAC6',
#  'TFs_and_others_KLF3',
#  'TFs_and_others_ZSCAN26',
#  'TFs_and_others_PBX3',
#  'TFs_and_others_ZKSCAN1',
#  'TFs_and_others_OGT',
#  'TFs_and_others_NKX2-1',
#  'TFs_and_others_CGGBP1',
#  'TFs_and_others_HIC2',
#  'TFs_and_others_SET',
#  'TFs_and_others_HOXD1',
#  'TFs_and_others_ZNF165',
#  'TFs_and_others_FOXA3',
#  'TFs_and_others_BNC2',
#  'TFs_and_others_DTL',
#  'Histone_H4K16ac',
#  'TFs_and_others_HOXC5',
#  'TFs_and_others_PHF5A',
#  'TFs_and_others_KDM4C',
#  'TFs_and_others_GZF1',
#  'TFs_and_others_TRIM33',
#  'TFs_and_others_DDX17',
#  'TFs_and_others_LHX2',
#  'TFs_and_others_NPM1',
#  'Histone_H3K27ac',
#  'TFs_and_others_SMARCA5',
#  'TFs_and_others_ZNF513',
#  'TFs_and_others_KAT8',
#  'TFs_and_others_ZNF510',
#  'TFs_and_others_ZNF597',
#  'Histone_H3K36ac',
#  'TFs_and_others_SMAD1',
#  'TFs_and_others_SRSF7',
#  'Histone_H3K9me1',
#  'TFs_and_others_YBX1',
#  'Histone_H3R8me2',
#  'TFs_and_others_AATF',
#  'TFs_and_others_GTF3C5',
#  'TFs_and_others_MLLT1',
#  'TFs_and_others_ARRB1',
#  'TFs_and_others_ILF3',
#  'TFs_and_others_ZNF532',
#  'TFs_and_others_MIF',
#  'TFs_and_others_BRD3',
#  'TFs_and_others_DUX4',
#  'TFs_and_others_CSRNP3',
#  'Histone_H3.3B',
#  'TFs_and_others_TCF25',
#  'TFs_and_others_METTL14',
#  'TFs_and_others_ZNF138',
#  'TFs_and_others_PIAS4',
#  'TFs_and_others_LMNA',
#  'TFs_and_others_CSDE1',
#  'TFs_and_others_SMARCA4',
#  'TFs_and_others_APOBEC3B',
#  'TFs_and_others_ZNF217',
#  'TFs_and_others_ZNF207',
#  'TFs_and_others_ZNF772',
#  'TFs_and_others_ELK1',
#  'TFs_and_others_RAG1',
#  'TFs_and_others_HDAC3',
#  'TFs_and_others_ETV1',
#  'TFs_and_others_BACH2',
#  'TFs_and_others_USF1',
#  'TFs_and_others_TBX18',
#  'TFs_and_others_HK2',
#  'TFs_and_others_PRDM14',
#  'TFs_and_others_JUN',
#  'TFs_and_others_STAT5',
#  'TFs_and_others_ZSCAN18',
#  'TFs_and_others_NFE2',
#  'TFs_and_others_BRD4',
#  'TFs_and_others_ID3',
#  'TFs_and_others_NOS2',
#  'TFs_and_others_ZNF800',
#  'TFs_and_others_NFIC',
#  'TFs_and_others_TSHZ2',
#  'RNA_polymerase_POLR3B',
#  'TFs_and_others_MEOX2',
#  'TFs_and_others_FOXH1',
#  'TFs_and_others_ATAD3A',
#  'TFs_and_others_NRL',
#  'Histone_H3T11ph',
#  'Histone_H3K9me3',
#  'TFs_and_others_ZNF529',
#  'Histone_H2AK119Ub',
#  'TFs_and_others_MEF2D',
#  'TFs_and_others_TAF1',
#  'TFs_and_others_FBP1',
#  'TFs_and_others_ZNF608',
#  'TFs_and_others_NR3C2',
#  'TFs_and_others_HDAC9',
#  'TFs_and_others_ZNF362',
#  'TFs_and_others_MAP1LC3B',
#  'TFs_and_others_MKI67',
#  'TFs_and_others_MNX1',
#  'TFs_and_others_TOP2B',
#  'TFs_and_others_E2F3',
#  'TFs_and_others_KMT2A',
#  'TFs_and_others_MYOD1',
#  'TFs_and_others_MSX2',
#  'TFs_and_others_TOP2A',
#  'TFs_and_others_ASCL2',
#  'TFs_and_others_ZCCHC11',
#  'TFs_and_others_SVS-1',
#  'TFs_and_others_ALKBH3',
#  'TFs_and_others_CHD7',
#  'TFs_and_others_EGFR',
#  'TFs_and_others_DMTF1',
#  'TFs_and_others_VEZF1',
#  'TFs_and_others_ONECUT1',
#  'TFs_and_others_TRIM22',
#  'TFs_and_others_Crotonyllysine',
#  'Histone_H1.4',
#  'TFs_and_others_SRSF9',
#  'Histone_H3K4me3',
#  'TFs_and_others_MCRS1',
#  'TFs_and_others_STAT1',
#  'TFs_and_others_MIER1',
#  'TFs_and_others_GATA2',
#  'TFs_and_others_NEIL1',
#  'TFs_and_others_CNOT3',
#  'TFs_and_others_HMGA1',
#  'TFs_and_others_MATR3',
#  'TFs_and_others_OLIG2',
#  'TFs_and_others_BMI',
#  'TFs_and_others_HMGN4',
#  'TFs_and_others_KLF16',
#  'Histone_H3R17me2',
#  'TFs_and_others_BCL3',
#  'TFs_and_others_ZNF677',
#  'TFs_and_others_NFIB',
#  'TFs_and_others_PHF8',
#  'Histone_H3K14cr',
#  'TFs_and_others_GGCT',
#  'TFs_and_others_ZNF431',
#  'TFs_and_others_PRDM2',
#  'TFs_and_others_NFYC',
#  'TFs_and_others_DRAP1',
#  'TFs_and_others_KAT5',
#  'TFs_and_others_EEA1',
#  'TFs_and_others_TFAM',
#  'TFs_and_others_NR1H4',
#  'TFs_and_others_NR0B1',
#  'TFs_and_others_MLL-AF4',
#  'TFs_and_others_SMC2',
#  'TFs_and_others_FOXF1',
#  'Histone_H2BK120ub',
#  'TFs_and_others_ZNF329',
#  'TFs_and_others_ASXL1',
#  'TFs_and_others_HDAC8',
#  'TFs_and_others_NR2E3',
#  'TFs_and_others_DR1',
#  'TFs_and_others_ZNF740',
#  'TFs_and_others_ARID1B',
#  'TFs_and_others_ZNF548',
#  'TFs_and_others_CPSF1',
#  'TFs_and_others_ZNF687',
#  'TFs_and_others_ASXL3',
#  'TFs_and_others_HMGN1',
#  'TFs_and_others_DIDO1',
#  'TFs_and_others_GLIS3',
#  'TFs_and_others_MED16',
#  'TFs_and_others_PKNOX1',
#  'Histone_H3K4me',
#  'TFs_and_others_ZIK1',
#  'TFs_and_others_HOXD13',
#  'TFs_and_others_ZNF282',
#  'TFs_and_others_KLF8',
#  'TFs_and_others_GMEB2',
#  'TFs_and_others_ZFP41',
#  'TFs_and_others_PBRM1',
#  'TFs_and_others_HIF1A',
#  'TFs_and_others_TOX',
#  'TFs_and_others_KDM4A',
#  'Histone_H3S10ph',
#  'TFs_and_others_LARP7',
#  'TFs_and_others_FOXA1',
#  'TFs_and_others_POLR2C',
#  'TFs_and_others_WDR61',
#  'TFs_and_others_L3MBTL3',
#  'TFs_and_others_FOXF2',
#  'TFs_and_others_ARHGAP35',
#  'TFs_and_others_ZNF266',
#  'TFs_and_others_SIX2',
#  'TFs_and_others_ZNF433',
#  'Histone_H3K27M',
#  'TFs_and_others_ZNF391',
#  'TFs_and_others_TFB2M',
#  'TFs_and_others_NUSAP1',
#  'TFs_and_others_CBX8',
#  'TFs_and_others_HJURP',
#  'TFs_and_others_ZNF212',
#  'TFs_and_others_MAML3',
#  'TFs_and_others_ZNF25',
#  'Histone_H2A.Z',
#  'TFs_and_others_NKX3-1',
#  'TFs_and_others_SMARCD1',
#  'Histone_H2BK5ac',
#  'TFs_and_others_PRDM6',
#  'TFs_and_others_KLF7',
#  'TFs_and_others_ZNF792',
#  'TFs_and_others_SP4',
#  'TFs_and_others_ZNF622',
#  'TFs_and_others_ZNF71',
#  'TFs_and_others_CHD4',
#  'TFs_and_others_REPIN1',
#  'TFs_and_others_SNRNP70',
#  'TFs_and_others_IKZF4',
#  'TFs_and_others_ZNF184',
#  'TFs_and_others_NR2F6',
#  'TFs_and_others_NRF1',
#  'TFs_and_others_MGMT',
#  'TFs_and_others_ATF5',
#  'TFs_and_others_TRAFD1',
#  'TFs_and_others_ZNF512B',
#  'TFs_and_others_ING5',
#  'RNA_polymerase_POLR2M',
#  'TFs_and_others_PADI2',
#  'TFs_and_others_MDN1',
#  'TFs_and_others_HOXB8',
#  'TFs_and_others_NELFE',
#  'TFs_and_others_RBL1',
#  'TFs_and_others_ZNF699',
#  'TFs_and_others_HEY1',
#  'TFs_and_others_EBF1',
#  'TFs_and_others_PRDM1',
#  'TFs_and_others_MAPK14',
#  'TFs_and_others_LRIF1',
#  'TFs_and_others_ERF',
#  'TFs_and_others_NKX2-8',
#  'Histone_H2A.ZK4K7ac',
#  'TFs_and_others_CEBPZ',
#  'TFs_and_others_PAX2',
#  'TFs_and_others_C7orf26',
#  'TFs_and_others_CTSG',
#  'TFs_and_others_HNRNPA2B1',
#  'TFs_and_others_EOMES',
#  'TFs_and_others_ZNF639',
#  'TFs_and_others_ZNF623',
#  'TFs_and_others_GLYR1',
#  'TFs_and_others_MECOM',
#  'TFs_and_others_GTF2F1',
#  'TFs_and_others_CCNE1',
#  'TFs_and_others_ZNF696',
#  'TFs_and_others_DEC1',
#  'TFs_and_others_ASF1A',
#  'TFs_and_others_ZNF281',
#  'TFs_and_others_THRB',
#  'TFs_and_others_TFE3',
#  'TFs_and_others_ZNF112',
#  'TFs_and_others_SP1',
#  'TFs_and_others_HMGN3',
#  'TFs_and_others_DDIT3',
#  'TFs_and_others_PRDM4',
#  'TFs_and_others_HDGF',
#  'TFs_and_others_CREBBP',
#  'TFs_and_others_FOXD3',
#  'TFs_and_others_GTF3C2',
#  'TFs_and_others_ZNF596',
#  'TFs_and_others_FOXP4',
#  'TFs_and_others_IRF1',
#  'TFs_and_others_MEIS2',
#  'TFs_and_others_5-hmC',
#  'TFs_and_others_ZNF256',
#  'TFs_and_others_SIX5',
#  'TFs_and_others_ZBED1',
#  'TFs_and_others_HOXC9',
#  'TFs_and_others_ZNF446',
#  'TFs_and_others_SNAPC4',
#  'TFs_and_others_CBX6',
#  'TFs_and_others_ZIC2',
#  'TFs_and_others_SAFB2',
#  'TFs_and_others_ZNF292',
#  'TFs_and_others_HINFP',
#  'TFs_and_others_E2F4',
#  'TFs_and_others_HOXB1',
#  'TFs_and_others_ZBTB1',
#  'TFs_and_others_LCORL',
#  'TFs_and_others_AHRR',
#  'TFs_and_others_ZNF674',
#  'TFs_and_others_ZNF197',
#  'TFs_and_others_CTR9',
#  'TFs_and_others_HDAC4',
#  'TFs_and_others_GPS2',
#  'TFs_and_others_TCF4',
#  'TFs_and_others_XBP1',
#  'TFs_and_others_ZBTB25',
#  'TFs_and_others_ETS1',
#  'TFs_and_others_LMNB1',
#  'TFs_and_others_CRX',
#  'TFs_and_others_NCOA3',
#  'TFs_and_others_NFIX',
#  'TFs_and_others_LEF1',
#  'TFs_and_others_TARDBP',
#  'TFs_and_others_ZBTB40',
#  'TFs_and_others_CBFB',
#  'TFs_and_others_CREB5',
#  'Histone_H3',
#  'TFs_and_others_CSNK2A1',
#  'TFs_and_others_ZNF784',
#  'TFs_and_others_ZNF79',
#  'TFs_and_others_WWTR1',
#  'TFs_and_others_SKP2',
#  'TFs_and_others_ZNF57',
#  'TFs_and_others_STAT2',
#  'TFs_and_others_BRCA2',
#  'Histone_H3.6',
#  'TFs_and_others_MTA2',
#  'TFs_and_others_ZNF511',
#  'TFs_and_others_ZNF775',
#  'TFs_and_others_ATF7',
#  'TFs_and_others_SRF',
#  'TFs_and_others_NR5A2',
#  'TFs_and_others_ZNF621',
#  'TFs_and_others_MEIS1',
#  'TFs_and_others_ZNF610',
#  'TFs_and_others_ELK4',
#  'TFs_and_others_MITF',
#  'TFs_and_others_TFDP1',
#  'TFs_and_others_METTL3',
#  'TFs_and_others_BrdU',
#  'TFs_and_others_GTF2B',
#  'TFs_and_others_PRDM11',
#  'TFs_and_others_TCF7L2',
#  'TFs_and_others_ZNF460',
#  'TFs_and_others_HES7',
#  'TFs_and_others_ZNF354C',
#  'Histone_H3K36me3',
#  'Histone_H2AT120ph',
#  'TFs_and_others_WDR5',
#  'TFs_and_others_ZNF583',
#  'TFs_and_others_AR',
#  'TFs_and_others_KDM6B',
#  'TFs_and_others_JMJD6',
#  'Histone_H3K18cr',
#  'TFs_and_others_ZBED5',
#  'TFs_and_others_FAM208A',
#  'TFs_and_others_MAX',
#  'TFs_and_others_AML1-ETO',
#  'TFs_and_others_WHSC1',
#  'TFs_and_others_NAIF1',
#  'TFs_and_others_MSC',
#  'TFs_and_others_XRCC3',
#  'TFs_and_others_KANSL1',
#  'TFs_and_others_KDM3A',
#  'TFs_and_others_SNIP1',
#  'TFs_and_others_MZF1',
#  'TFs_and_others_ZNF701',
#  'TFs_and_others_INO80',
#  'TFs_and_others_HAT1',
#  'TFs_and_others_NR1H2',
#  'TFs_and_others_ZNF350',
#  'Histone_H3K4ox',
#  'TFs_and_others_MBD4',
#  'TFs_and_others_NUP153',
#  'TFs_and_others_JUNB',
#  'TFs_and_others_SIRT3',
#  'TFs_and_others_ZBTB48',
#  'TFs_and_others_HOXB5',
#  'TFs_and_others_C10orf12',
#  'TFs_and_others_MTA1',
#  'TFs_and_others_BRDT',
#  'TFs_and_others_ZNF24',
#  'TFs_and_others_CEBPE',
#  'TFs_and_others_ZNF404',
#  'TFs_and_others_SMC1B',
#  'TFs_and_others_ZBTB5',
#  'TFs_and_others_ZSCAN22',
#  'TFs_and_others_MYF5',
#  'TFs_and_others_TEF',
#  'TFs_and_others_HNRNPLL',
#  'TFs_and_others_ZNF221',
#  'TFs_and_others_ZNF341',
#  'TFs_and_others_HMGB1',
#  'TFs_and_others_ETV2',
#  'TFs_and_others_PHF21A',
#  'TFs_and_others_NR2C2',
#  'TFs_and_others_ACTR5',
#  'TFs_and_others_FOXB1',
#  'TFs_and_others_ZNF761',
#  'TFs_and_others_ZNF720',
#  'TFs_and_others_GLMP',
#  'TFs_and_others_ATR',
#  'TFs_and_others_NCOA5',
#  'TFs_and_others_FOXO3',
#  'TFs_and_others_WIZ',
#  'TFs_and_others_CASP3',
#  'TFs_and_others_TLE3',
#  'TFs_and_others_NAT10',
#  'TFs_and_others_ZNF134',
#  'TFs_and_others_TTF2',
#  'TFs_and_others_ZNF843',
#  'TFs_and_others_MYOCD',
#  'TFs_and_others_KDM5D',
#  'TFs_and_others_INTS6',
#  'TFs_and_others_FOXM1',
#  'TFs_and_others_ZNF280A',
#  'TFs_and_others_ZGPAT',
#  'TFs_and_others_SREBF2',
#  'TFs_and_others_RREB1',
#  'TFs_and_others_TCEAL8',
#  'TFs_and_others_SERPINE1',
#  'Histone_H3T6ph',
#  'TFs_and_others_AHDC1',
#  'TFs_and_others_ZXDB',
#  'Histone_H4K5bu',
#  'TFs_and_others_ZBTB12',
#  'TFs_and_others_UBTF',
#  'TFs_and_others_TEAD1',
#  'TFs_and_others_EGR1',
#  'TFs_and_others_FOXC1',
#  'TFs_and_others_MIER3',
#  'TFs_and_others_CCDC101',
#  'Histone_H2B',
#  'TFs_and_others_TET2',
#  'TFs_and_others_KDM5A',
#  'TFs_and_others_KMT2D',
#  'Histone_H3K18ac',
#  'TFs_and_others_RXRA',
#  'TFs_and_others_ZBTB2',
#  'TFs_and_others_CHAMP1',
#  'TFs_and_others_MCM2',
#  'TFs_and_others_HOXA11',
#  'TFs_and_others_ZNF33A',
#  'TFs_and_others_DMC1',
#  'TFs_and_others_ZNF491',
#  'TFs_and_others_ZNF512',
#  'TFs_and_others_RHOXF2B',
#  'TFs_and_others_ZNF717',
#  'TFs_and_others_IRF9',
#  'TFs_and_others_MED21',
#  'TFs_and_others_HES4',
#  'TFs_and_others_ZFP69B',
#  'TFs_and_others_ID4',
#  'TFs_and_others_HSF1',
#  'Histone_H2A.XS139ph',
#  'TFs_and_others_Cyclobutane pyrimidine dimers',
#  'RNA_polymerase_POLR2G',
#  'TFs_and_others_ARID1A',
#  'TFs_and_others_MED26',
#  'TFs_and_others_SOX8',
#  'TFs_and_others_BHLHE40',
#  'TFs_and_others_THAP8',
#  'TFs_and_others_KLF1',
#  'Histone_H3T45ph',
#  'TFs_and_others_ID1',
#  'TFs_and_others_ZNF516',
#  'TFs_and_others_ZNF776',
#  'TFs_and_others_IRF3',
#  'TFs_and_others_RNF219',
#  'Histone_H1.4S187ph',
#  'TFs_and_others_YY1',
#  'TFs_and_others_BATF',
#  'TFs_and_others_INTS13',
#  'TFs_and_others_HEY2',
#  'TFs_and_others_SPDEF',
#  'TFs_and_others_ZNF707',
#  'TFs_and_others_SP3',
#  'TFs_and_others_GLIS1',
#  'TFs_and_others_PLSCR1',
#  'TFs_and_others_FERD3L',
#  'TFs_and_others_ZSCAN29',
#  'TFs_and_others_ZBTB26',
#  'Histone_H3.3',
#  'TFs_and_others_SMARCA1',
#  'TFs_and_others_NUP214',
#  'TFs_and_others_RCOR2',
#  'TFs_and_others_IRF8',
#  'TFs_and_others_ZNF488',
#  'TFs_and_others_TCF15',
#  'TFs_and_others_GABPB2',
#  'TFs_and_others_MYB',
#  'TFs_and_others_ZNF574',
#  'TFs_and_others_MED8',
#  'TFs_and_others_SRPK2',
#  'TFs_and_others_ZMYM3',
#  'TFs_and_others_LHX4',
#  'TFs_and_others_ARNTL',
#  'TFs_and_others_NEUROD1',
#  'TFs_and_others_SCRT2',
#  'TFs_and_others_SOX17',
#  'TFs_and_others_TRMT112',
#  'TFs_and_others_MAFF',
#  'TFs_and_others_MSH6',
#  'Histone_H1.5',
#  'TFs_and_others_ORC2',
#  'TFs_and_others_ZNF641',
#  'TFs_and_others_MEPCE',
#  'TFs_and_others_HBZ',
#  'TFs_and_others_MAFB',
#  'TFs_and_others_ZNF296',
#  'TFs_and_others_LYL1',
#  'TFs_and_others_RUNX1T1',
#  'TFs_and_others_CDAN1',
#  'Histone_H3.Y',
#  'TFs_and_others_PDS5A',
#  'TFs_and_others_ZBTB46',
#  'TFs_and_others_UBP1',
#  'Histone_H3K27me3',
#  'TFs_and_others_EWSR1',
#  'Histone_H2BK15ac',
#  'TFs_and_others_PPP1R10',
#  'TFs_and_others_JADE3',
#  'TFs_and_others_GABPB1',
#  'TFs_and_others_IRF4',
#  'TFs_and_others_RARB',
#  'TFs_and_others_IRF2',
#  'TFs_and_others_TRIM37',
#  'TFs_and_others_KDM5C',
#  'TFs_and_others_RTA',
#  'TFs_and_others_DMAP1',
#  'TFs_and_others_RXRB',
#  'TFs_and_others_5-mC',
#  'TFs_and_others_OSR2',
#  'TFs_and_others_DDX55',
#  'Histone_H2',
#  'TFs_and_others_ZNF850',
#  'TFs_and_others_CHD1',
#  'TFs_and_others_ZBTB21',
#  'TFs_and_others_HIVEP1',
#  'TFs_and_others_ZNF709',
#  'TFs_and_others_ILK',
#  'TFs_and_others_ZNF473',
#  'TFs_and_others_NFATC4',
#  'TFs_and_others_SUMO1',
#  'TFs_and_others_FGFR1',
#  'TFs_and_others_PSMB5',
#  'TFs_and_others_RFX1',
#  'TFs_and_others_CBFA2T2',
#  'TFs_and_others_PBX2',
#  'TFs_and_others_SIX1',
#  'TFs_and_others_ZMAT3',
#  'TFs_and_others_CBX7',
#  'Histone_H4K4me3',
#  'Histone_Pan lysine acetylation',
#  'TFs_and_others_ZNF398',
#  'TFs_and_others_EHMT2',
#  'TFs_and_others_ZNF30',
#  'TFs_and_others_GATAD1',
#  'TFs_and_others_RUVBL1',
#  'TFs_and_others_SS18L1',
#  'TFs_and_others_GLTSCR1',
#  'Histone_H3K36me1',
#  'TFs_and_others_HOXB6',
#  'TFs_and_others_TAF5L',
#  'TFs_and_others_BCLAF1',
#  'TFs_and_others_PRMT1',
#  'TFs_and_others_ELAVL1',
#  'TFs_and_others_ZNF670',
#  'TFs_and_others_ARID4A',
#  'TFs_and_others_MYRF',
#  'TFs_and_others_TRIM25',
#  'TFs_and_others_IFI16',
#  'TFs_and_others_NR2F2',
#  'TFs_and_others_MCM7',
#  'TFs_and_others_HNF1B',
#  'TFs_and_others_ZNF346',
#  'RNA_polymerase_POLR3A',
#  'TFs_and_others_KDM6A',
#  'TFs_and_others_RYBP',
#  'RNA_polymerase_POLR2A',
#  'TFs_and_others_TBP',
#  'TFs_and_others_ZNF324',
#  'TFs_and_others_TAZ',
#  'TFs_and_others_PHB',
#  'TFs_and_others_NEDD4',
#  'TFs_and_others_OTX1',
#  'TFs_and_others_TBX2',
#  'TFs_and_others_RAG2',
#  'TFs_and_others_NELFB',
#  'TFs_and_others_MED9',
#  'TFs_and_others_ZNF585B',
#  'TFs_and_others_BAHD1',
#  'TFs_and_others_BEND3',
#  'TFs_and_others_ZNF174',
#  'TFs_and_others_MYH11',
#  'TFs_and_others_EPOP',
#  'TFs_and_others_EBV-ZEBRA',
#  'TFs_and_others_FOXN3',
#  'TFs_and_others_PCGF6',
#  'Histone_H2A',
#  'TFs_and_others_KLF4',
#  'TFs_and_others_ZNF557',
#  'TFs_and_others_ZNF250',
#  'Histone_macroH2A1',
#  'TFs_and_others_MED1',
#  'TFs_and_others_KMT2C',
#  'TFs_and_others_HOXC11',
#  'TFs_and_others_NME2',
#  'Histone_H3K5ac',
#  'TFs_and_others_NPAT',
#  'TFs_and_others_ZNF37A',
#  'Histone_H3K9Kac',
#  'TFs_and_others_MBD5',
#  'TFs_and_others_ZNF558',
#  'RNA_polymerase_POLR3GL',
#  'TFs_and_others_ZNF354B',
#  'TFs_and_others_ZNF780A',
#  'TFs_and_others_CPSF2',
#  'TFs_and_others_BACH1',
#  'Histone_H3K9ac',
#  'TFs_and_others_COBLL1',
#  'TFs_and_others_ZNF607',
#  'TFs_and_others_HOXD4',
#  'TFs_and_others_TRERF1',
#  'TFs_and_others_PITX3',
#  'TFs_and_others_OVOL1',
#  'TFs_and_others_ATM',
#  'TFs_and_others_ZNF20',
#  'TFs_and_others_SMARCAL1',
#  'Histone_H4',
#  'TFs_and_others_EED',
#  'TFs_and_others_ZNF543',
#  'TFs_and_others_STAG3',
#  'TFs_and_others_CPSF6',
#  'TFs_and_others_MBD2',
#  'TFs_and_others_SUPT20H',
#  'TFs_and_others_PSIP1',
#  'TFs_and_others_ZBTB37',
#  'TFs_and_others_SMAD5',
#  'TFs_and_others_HOXA7',
#  'TFs_and_others_SF3B1',
#  'TFs_and_others_SOX5',
#  'TFs_and_others_AKNA',
#  'TFs_and_others_ZSCAN31',
#  'TFs_and_others_RFX2',
#  'TFs_and_others_CDX2',
#  'TFs_and_others_IKZF5',
#  'TFs_and_others_QSER1',
#  'Histone_H2BK20ac',
#  'TFs_and_others_PTBP1',
#  'TFs_and_others_ZNF155',
#  'TFs_and_others_INSM2',
#  'TFs_and_others_NCOA1',
#  'TFs_and_others_SMARCC1',
#  'TFs_and_others_NCOA2',
#  'TFs_and_others_ZNF343',
#  'TFs_and_others_ZNF319',
#  'TFs_and_others_ZNF768',
#  'TFs_and_others_LMTK3',
#  'TFs_and_others_HNRNPUL1',
#  'TFs_and_others_WDR77',
#  'TFs_and_others_RARA',
#  'TFs_and_others_SUPT16H',
#  'TFs_and_others_NR2E1',
#  'TFs_and_others_HOXB2',
#  'TFs_and_others_ZNF692',
#  'TFs_and_others_DDX39B',
#  'TFs_and_others_ATF1',
#  'TFs_and_others_DPPA3',
#  'Histone_H3K27me1',
#  'TFs_and_others_HOXD9',
#  'TFs_and_others_ZNF660',
#  'TFs_and_others_ZXDC',
#  'TFs_and_others_GFI1B',
#  'TFs_and_others_GLI1',
#  'TFs_and_others_ING4',
#  'TFs_and_others_ZNF615',
#  'TFs_and_others_ZSCAN20',
#  'TFs_and_others_ZNF572',
#  'TFs_and_others_CEBPG',
#  'TFs_and_others_8-Hydroxydeoxyguanosine',
#  'TFs_and_others_AIM2',
#  'TFs_and_others_ZNF777',
#  'TFs_and_others_ZNF668',
#  'Histone_H1',
#  'TFs_and_others_MethylCap',
#  'TFs_and_others_PBX4',
#  'TFs_and_others_SPIN1',
#  'Histone_H4K5K8K12K16ac',
#  'TFs_and_others_ZNF865',
#  'TFs_and_others_SLFN5',
#  'TFs_and_others_ZNF280D',
#  'TFs_and_others_ZNF614',
#  'TFs_and_others_CUL4B',
#  'TFs_and_others_LHX5',
#  'TFs_and_others_ZMYND11',
#  'TFs_and_others_COPS2',
#  'Histone_H4K20me2',
#  'TFs_and_others_ZNF791',
#  'TFs_and_others_DLX6',
#  'TFs_and_others_SMAD4',
#  'TFs_and_others_ZNF580',
#  'TFs_and_others_ZBTB33',
#  'TFs_and_others_N6AMT1',
#  'Histone_H4K5K8ac',
#  'TFs_and_others_RNF20',
#  'TFs_and_others_THAP4',
#  'TFs_and_others_ZNF671',
#  'TFs_and_others_NR1H3',
#  'TFs_and_others_ZNF462',
#  'TFs_and_others_MYBL2',
#  'TFs_and_others_ICE2',
#  'TFs_and_others_ZNF652',
#  'TFs_and_others_NCOA4',
#  'TFs_and_others_MYF6',
#  'TFs_and_others_NKX2-3',
#  'TFs_and_others_RBBP7',
#  'TFs_and_others_CDK7',
#  'TFs_and_others_XRCC1',
#  'TFs_and_others_FOXP3',
#  'TFs_and_others_NKRF',
#  'TFs_and_others_RAD21L1',
#  'TFs_and_others_ZBTB44',
#  'TFs_and_others_ZNF195',
#  'TFs_and_others_JMJD1C',
#  'TFs_and_others_ZNF747',
#  'Histone_H3.5',
#  'TFs_and_others_MLL-AF6',
#  'TFs_and_others_MXI1',
#  'TFs_and_others_KDM2B',
#  'TFs_and_others_THAP1',
#  'TFs_and_others_REC8',
#  'TFs_and_others_TGIF2',
#  'TFs_and_others_MXD4',
#  'TFs_and_others_TAF3',
#  'TFs_and_others_ZNF3',
#  'TFs_and_others_PCF11',
#  'TFs_and_others_KDM1A',
#  'Histone_H3.3 K27M mutant',
#  'TFs_and_others_CDYL2',
#  'TFs_and_others_THAP11',
#  'TFs_and_others_ALKBH1',
#  'TFs_and_others_ZNF397',
#  'TFs_and_others_ISL2',
#  'TFs_and_others_OTX2',
#  'Histone_H2BS112GlcNAc',
#  'TFs_and_others_EZH1',
#  'Histone_H1.4K34ac',
#  'TFs_and_others_RELB',
#  'TFs_and_others_HBcAg',
#  'TFs_and_others_ULK3',
#  'TFs_and_others_NETO2',
#  'TFs_and_others_ATXN7L3',
#  'TFs_and_others_VSX2',
#  'TFs_and_others_ESR2',
#  'Histone_macroH2A1.2',
#  'TFs_and_others_POU5F1',
#  'TFs_and_others_ZNF837',
#  'TFs_and_others_ZNF180',
#  'TFs_and_others_TP53BP1',
#  'TFs_and_others_CDT1',
#  'TFs_and_others_MYCN',
#  'TFs_and_others_ZNF19',
#  'TFs_and_others_ZNF318',
#  'TFs_and_others_ELANE',
#  'TFs_and_others_MGA',
#  'TFs_and_others_DZIP1',
#  'RNA_polymerase_RNA polymerase III',
#  'TFs_and_others_TCF21',
#  'TFs_and_others_ZFP64',
#  'TFs_and_others_SUV39H1',
#  'TFs_and_others_ZNF140',
#  'TFs_and_others_ZNF230',
#  'TFs_and_others_CSTF3',
#  'TFs_and_others_CDK11A',
#  'TFs_and_others_E2F6',
#  'TFs_and_others_TBX3',
#  'TFs_and_others_SOD1',
#  'TFs_and_others_FEZF1',
#  'TFs_and_others_ZNF75A',
#  'TFs_and_others_CRTC1',
#  'TFs_and_others_G-quadruplex',
#  'TFs_and_others_BAP1',
#  'TFs_and_others_CTBP2',
#  'TFs_and_others_TRF2',
#  'TFs_and_others_MLLT10',
#  'TFs_and_others_ZHX3',
#  'TFs_and_others_GLIS2',
#  'TFs_and_others_ZNF132',
#  'TFs_and_others_MTA3',
#  'TFs_and_others_GFI1',
#  'TFs_and_others_ZNF530',
#  'TFs_and_others_CIZ1',
#  'TFs_and_others_MCPV ST',
#  'TFs_and_others_TGIF2LX',
#  'TFs_and_others_ZBTB6',
#  'TFs_and_others_SMC1A',
#  'TFs_and_others_MGEA5',
#  'RNA_polymerase_POLR2B',
#  'TFs_and_others_CBX1',
#  'Histone_H4K5ac',
#  'TFs_and_others_HIVEP3',
#  'TFs_and_others_PDX1',
#  'TFs_and_others_CUL3',
#  'TFs_and_others_EHF',
#  'TFs_and_others_CC2D1A',
#  'Histone_H3K31ac',
#  'TFs_and_others_ZFX',
#  'TFs_and_others_HIRA',
#  'TFs_and_others_CD74',
#  'Histone_H4K12ac',
#  'TFs_and_others_ZFP36',
#  'Histone_H2A.Z.1',
#  'TFs_and_others_ZNF764',
#  'TFs_and_others_ZBTB14',
#  'TFs_and_others_NFATC2',
#  'TFs_and_others_FOXP2',
#  'TFs_and_others_POU2F3',
#  ...]

# %% [markdown]
# # Data selection

# %%
from torch.utils import data

class Dataset(data.Dataset):
    def __init__(self, chroms, features,
                 dna_source, features_source,
                 labels_source, intervals, lrp_feat=[]):
        self.chroms = chroms
        self.features = features
        self.dna_source = dna_source
        self.features_source = features_source
        self.labels_source = labels_source
        self.intervals = intervals
        self.le = LabelBinarizer().fit(np.array([["A"], ["C"], ["T"], ["G"]]))
        self.lrp_feat = lrp_feat

    def __len__(self):
        return len(self.intervals)

    def __getitem__(self, index):
        interval = self.intervals[index]
        chrom = interval[0]
        begin = int(interval[1])
        end = int(interval[2])
        dna_OHE = self.le.transform(list(self.dna_source[chrom][begin:end].upper()))

        feature_matr = []
        for feature in self.features:
            source = self.features_source[feature]
            feature_matr.append(source[chrom][begin:end])
        if len(feature_matr) > 0:
            X = np.hstack((dna_OHE, np.array(feature_matr).T/1000)).astype(np.float32)
        else:
            X = dna_OHE.astype(np.float32)
        y = self.labels_source[interval[0]][interval[1]: interval[2]]
        if len(self.lrp_feat) > 0:
            X = X[:,np.sort(lrp_feat)]

        return (X, y)

# %%
width = 100

np.random.seed(10)

ints_in = []
ints_out = []

for chrm in chrom_names:
    for st in trange(0, ZDNA[chrm].shape - width, width):
        interval = [st, min(st + width, ZDNA[chrm].shape)]
        if ZDNA[chrm][interval[0]: interval[1]].any():
            ints_in.append([chrm, interval[0], interval[1]])
        else:
            ints_out.append([chrm, interval[0], interval[1]])

ints_in = np.array(ints_in)
ints_out = np.array(ints_out)[np.random.choice(range(len(ints_out)), size=len(ints_in) * 2, replace=False)]
# Out:
# 100%|██████████████████████████████████████████████████████████████████████| 2489564/2489564 [00:34<00:00, 71904.43it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 2421935/2421935 [00:32<00:00, 74311.42it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 1982955/1982955 [00:26<00:00, 75117.02it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 1902145/1902145 [00:25<00:00, 74047.37it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 1815382/1815382 [00:24<00:00, 73112.44it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 1708059/1708059 [00:22<00:00, 76102.19it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 1593459/1593459 [00:21<00:00, 72596.07it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 1451386/1451386 [00:18<00:00, 77119.10it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 1383947/1383947 [00:19<00:00, 70155.78it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 1337974/1337974 [00:17<00:00, 77318.78it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 1350866/1350866 [00:17<00:00, 76703.74it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 1332753/1332753 [00:17<00:00, 76087.06it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 1143643/1143643 [00:16<00:00, 68575.03it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 1070437/1070437 [00:14<00:00, 76454.57it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 1019911/1019911 [00:13<00:00, 77951.05it/s]
# 100%|████████████████████████████████████████████████████████████████████████| 903383/903383 [00:11<00:00, 77081.39it/s]
# 100%|████████████████████████████████████████████████████████████████████████| 832574/832574 [00:10<00:00, 76943.24it/s]
# 100%|████████████████████████████████████████████████████████████████████████| 803732/803732 [00:12<00:00, 62626.19it/s]
# 100%|████████████████████████████████████████████████████████████████████████| 586176/586176 [00:07<00:00, 75231.73it/s]
# 100%|████████████████████████████████████████████████████████████████████████| 644441/644441 [00:08<00:00, 75056.22it/s]
# 100%|████████████████████████████████████████████████████████████████████████| 467099/467099 [00:06<00:00, 75127.22it/s]
# 100%|████████████████████████████████████████████████████████████████████████| 508184/508184 [00:06<00:00, 74702.43it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 1560408/1560408 [00:20<00:00, 75487.56it/s]
# 100%|████████████████████████████████████████████████████████████████████████| 572274/572274 [00:07<00:00, 76164.92it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 165/165 [00:00<00:00, 59675.79it/s]

# %%
np.random.seed(42)
equalized = np.vstack((ints_in, ints_out))
equalized = [[inter[0], int(inter[1]), int(inter[2])] for inter in equalized]

train_inds, test_inds = next(StratifiedKFold().split(equalized, [f"{int(i < 400)}_{elem[0]}"
                                                                 for i, elem
                                                                 in enumerate(equalized)]))

train_intervals, test_intervals = [equalized[i] for i in train_inds], [equalized[i] for i in test_inds]

# %%
params = {'batch_size':32,
          'num_workers':4,
          'shuffle':True}

train_dataset = Dataset(chrom_names, feature_names, 
                       DNA, DNA_features, 
                       ZDNA, train_intervals, lrp_feat = [])

test_dataset = Dataset(chrom_names, feature_names, 
                       DNA, DNA_features, 
                       ZDNA, test_intervals, lrp_feat = [])

loader_train = data.DataLoader(train_dataset, **params)
loader_test = data.DataLoader(test_dataset, **params)

# %% [markdown]
# # All models

# %%
from torch import nn
import torch.nn.functional as F
from sklearn.metrics import roc_auc_score, f1_score, average_precision_score, recall_score
from IPython.display import clear_output

# %%
#CNN model
class DeepCNNLayerNorm(nn.Module):
    def __init__(self):
        super().__init__()
        self.seq = nn.Sequential(
            nn.Conv2d(1, 3, kernel_size=(3, 3), padding=1),
            nn.LayerNorm([3, 100, 1950]),
            nn.ReLU(),
            
            nn.Conv2d(3, 3, kernel_size=(5, 5), padding=2),
            nn.ReLU(),
            
            nn.Conv2d(3, 1, kernel_size=(3, 3), padding=1),
            nn.LayerNorm([1, 100, 1950]),  # Укажите размеры после свертки
            nn.ReLU(),
            
            nn.Dropout(0.25),
            
            nn.Linear(1950, 500),
            nn.Dropout(0.25),
            nn.ReLU(),
            
            nn.Linear(500, 2)
        )

    def forward(self, x):
        batch = x.shape[0]
        x = x.reshape(batch, 1, width, 1950)
        x = self.seq(x)
        x = torch.squeeze(x)
        x = F.log_softmax(x, dim=-1)
        return x

# %%
#CNN model
class DeepCNNBatchNorm(nn.Module):
    def __init__(self):
        super().__init__()
        self.seq = nn.Sequential(
            nn.Conv2d(1, 3, kernel_size=(3, 3), padding=1),
            nn.BatchNorm2d(3),
            nn.ReLU(),
            
            nn.Conv2d(3, 3, kernel_size=(5, 5), padding=2),
            nn.ReLU(),
            
            nn.Conv2d(3, 1, kernel_size=(3, 3), padding=1),
            nn.BatchNorm2d(1),
            nn.ReLU(),
            
            nn.Dropout(0.25),
            nn.Linear(1950, 500),
            nn.Dropout(0.25),
            nn.ReLU(),
            nn.Linear(500, 2)
        )

    def forward(self, x):
        batch = x.shape[0]
        x = x.reshape(batch, 1, width, 1950)
        x = self.seq(x)
        x = torch.squeeze(x)
        x = F.log_softmax(x, dim=-1)
        return x

# %%
class DeepCNNInstanceNorm(nn.Module):
    def __init__(self):
        super().__init__()
        self.seq = nn.Sequential(
            nn.Conv2d(1, 3, kernel_size=(3, 3), padding=1),
            nn.InstanceNorm2d(3),
            nn.ReLU(),
            
            nn.Conv2d(3, 3, kernel_size=(5, 5), padding=2),
            nn.ReLU(),
            
            nn.Conv2d(3, 1, kernel_size=(3, 3), padding=1),
            nn.InstanceNorm2d(1),
            nn.ReLU(),
            
            nn.Dropout(0.25),
            
            nn.Linear(1950, 500),
            nn.Dropout(0.25),
            nn.ReLU(),
            
            nn.Linear(500, 2)
        )

    def forward(self, x):
        batch = x.shape[0]
        x = x.reshape(batch, 1, width, 1950)
        x = self.seq(x)
        x = torch.squeeze(x)
        x = F.log_softmax(x, dim=-1)
        return x

# %% [markdown]
# # Train and test

# %%
import time
from sklearn.metrics import roc_auc_score, f1_score, precision_score, recall_score

def loss_func(output, y_batch):
    return torch.nn.NLLLoss()(output, y_batch)


def train_epoch(model, optimizer):
    roc_auc_log, precision_log, recall_log, f1_log, acc_log, loss_log = [], [], [], [], [], []
    model.train()
    for X_batch, y_batch in loader_train:
        X_batch, y_batch = X_batch.cuda(), y_batch.cuda().long()
        optimizer.zero_grad()
        
        output = model(X_batch)
        
        pred = torch.argmax(output, dim=-1)
        y_pred = nn.Softmax(dim=-1)(output)[..., 1].detach().cpu().numpy().flatten()
        
        if np.std(y_batch.cpu().numpy().flatten()) == 0:
            roc_auc = 0
            precision = 0
            recall = 0
        else:
            roc_auc = roc_auc_score(y_batch.cpu().numpy().flatten(),
                                    y_pred)
            precision = precision_score(y_batch.cpu().numpy().flatten(), pred.cpu().numpy().flatten())
            recall = recall_score(y_batch.cpu().numpy().flatten(), pred.cpu().numpy().flatten())
        
        
        roc_auc_log.append(roc_auc)
        precision_log.append(precision)
        recall_log.append(recall)
        
        
        f1_log.append(f1_score(y_batch.cpu().numpy().flatten(),
                         pred.cpu().numpy().flatten()))

        acc = torch.mean((pred == y_batch).float())
        acc_log.append(acc.cpu().numpy())
        
        loss = loss_func(output.permute([0, 2, 1]), y_batch)
        loss.backward()
        optimizer.step()
        loss = loss.item()
        loss_log.append(loss)
        
    return roc_auc_log, precision_log, recall_log, f1_log, acc_log, loss_log

def test(model):
    roc_auc_log, precision_log, recall_log, f1_log, acc_log, loss_log = [], [], [], [], [], []
    model.eval()
    means = []
    for X_batch, y_batch in loader_test:
        X_batch, y_batch = X_batch.cuda(), y_batch.cuda().long()
        output = model(X_batch)
        means.append(y_batch.sum().cpu() / (1.0 * y_batch.shape[0]))
        
        pred = torch.argmax(output, dim=-1)
        y_pred = nn.Softmax(dim=-1)(output)[..., 1].detach().cpu().numpy().flatten()
        
        if np.std(y_batch.cpu().numpy().flatten()) == 0:
            roc_auc = 0
            precision = 0
            recall = 0
        else:
            roc_auc = roc_auc_score(y_batch.cpu().numpy().flatten(),
                                    y_pred)
            precision = precision_score(y_batch.cpu().numpy().flatten(), pred.cpu().numpy().flatten())
            recall = recall_score(y_batch.cpu().numpy().flatten(), pred.cpu().numpy().flatten())
        
        
        roc_auc_log.append(roc_auc)
        precision_log.append(precision)
        recall_log.append(recall)
        
        f1 = f1_score(y_batch.cpu().numpy().flatten(),
                                  pred.cpu().numpy().flatten())
        
        f1_log.append(f1)
        
        acc = torch.mean((pred == y_batch).float())
        acc_log.append(acc.cpu().numpy())
        
        if output.dim() == 2:  
            output = output.unsqueeze(0)
        loss = loss_func(output.permute([0, 2, 1]), y_batch)
        loss = loss.item()
        loss_log.append(loss)
        
    return roc_auc_log, precision_log, recall_log, f1_log, acc_log, loss_log

def plot_history(train_history, valid_history, title, BatchSize, epoch_to_show=20):
    plt.figure(figsize=(epoch_to_show, 4))
    plt.title(title)    
    
    epoch_num = len(valid_history)
    train_history = np.array([None] * (BatchSize * epoch_to_show) + train_history)
    valid_history = np.array([None] * epoch_to_show + valid_history)
    
    plt.plot(np.linspace(epoch_num-epoch_to_show+1, epoch_num+1, (epoch_to_show+1)*BatchSize), 
             train_history[-(epoch_to_show+1)*BatchSize:], c='red', label='train')
    plt.plot(np.linspace(epoch_num-epoch_to_show+1, epoch_num+1, epoch_to_show+1),
                valid_history[-epoch_to_show-1:], c='green', label='test')
    
    plt.ylim((0, 1))
    plt.yticks(np.linspace(0, 1, 11))
    plt.xticks(np.arange(epoch_num-epoch_to_show+1, epoch_num+2), 
              np.arange(epoch_num-epoch_to_show, epoch_num+1).astype(int))
    plt.xlabel('train steps')
    plt.legend(loc='best')
    plt.grid()
    plt.show()
    
def train(model, opt, n_epochs):
    train_auc_log, train_pr_log, train_rec_log, train_f1_log, train_acc_log, train_loss_log = [], [], [], [], [], []
    val_auc_log, val_pr_log, val_rec_log, val_f1_log, val_acc_log, val_loss_log = [], [], [], [], [], []
    times = []
    
    for epoch in range(n_epochs):
        print("Epoch {} of {}".format(epoch + 1, n_epochs))
        
        start_time = time.time()
        
        train_auc, train_pr, train_rec, train_f1, train_acc, train_loss = train_epoch(model, opt)
        val_auc, val_pr, val_rec, val_f1, val_acc, val_loss = test(model)
        
        end_time = time.time()
        t = end_time - start_time
        times.append(t)
        
        BatchSize = len(train_loss)
        
        train_auc_log.extend(train_auc)
        train_pr_log.extend(train_pr)
        train_rec_log.extend(train_rec)
        train_f1_log.extend(train_f1)
        train_acc_log.extend(train_acc)
        train_loss_log.extend(train_loss)

        val_auc_log.append(np.mean(val_auc))
        val_pr_log.append(np.mean(val_pr))
        val_rec_log.append(np.mean(val_rec))
        val_f1_log.append(np.mean(val_f1))
        val_acc_log.append(np.mean(val_acc))
        val_loss_log.append(np.mean(val_loss))
        
#         raise BaseException
        
        if (epoch % 1) == 0:
            clear_output()
            plot_history(train_loss_log, val_loss_log, 'Loss', len(train_loss))
            plot_history(train_auc_log, val_auc_log, 'Auc', len(train_loss))
            plot_history(train_pr_log, val_pr_log, 'Precision', len(train_loss))
            plot_history(train_rec_log, val_rec_log, 'Recall', len(train_loss))
            plot_history(train_f1_log, val_f1_log, 'F1', len(train_loss))
            print("Time: ", t/60)
            print("Epoch {}: ROC-AUC = {:.2%}".format(epoch+1, val_auc_log[-1]))
            print("Epoch {}: Precision = {:.3}".format(epoch+1, val_pr_log[-1]))
            print("Epoch {}: Recall = {:.3}".format(epoch+1, val_rec_log[-1]))
            print("Epoch {}: F1-score = {:.3}".format(epoch+1, val_f1_log[-1]))
            
           
    print("Final ROC-AUC = {:.4}%".format(val_auc_log[-1]*100))
    print("Final Precision = {:.3}".format(val_pr_log[-1]))
    print("Final Recall = {:.3}".format(val_rec_log[-1]))
    print("Final F1-score = {:.3}".format(val_f1_log[-1]))
    return val_auc_log, val_pr_log, val_rec_log, val_f1_log, val_acc_log, val_loss_log, times

# %% [markdown]
# # Эксперименты со слоями нормализации

# %% [markdown]
# ## Эксперимент LayerNorm

# %%
set_random_seed(42)
torch.cuda.empty_cache()

model = DeepCNNLayerNorm()
model = model.cuda()

opt = torch.optim.Adam(model.parameters(), lr=10**-4, weight_decay=10**-4)

val_auc_log, val_pr_log, val_rec_log, val_f1_log, val_acc_log, val_loss_log, times = train(model, opt, 10)
# Out:
# Time:  15.396828885873159
# Epoch 10: ROC-AUC = 81.69%
# Epoch 10: Precision = 0.774
# Epoch 10: Recall = 0.356
# Epoch 10: F1-score = 0.487
# Final ROC-AUC = 81.69%
# Final Precision = 0.774
# Final Recall = 0.356
# Final F1-score = 0.487

# %%
print("Epoch {}".format(np.argmax(val_f1_log)))
print("Max F1-score: {:.4f}%".format(val_f1_log[np.argmax(val_f1_log)]*100))
print("ROC-AUC: {:.4f}%".format(val_auc_log[np.argmax(val_f1_log)]*100))
print("Precision: {:.4f}".format(val_pr_log[np.argmax(val_f1_log)]))
print("Recall: {:.4f}".format(val_rec_log[np.argmax(val_f1_log)]))

print("Mean time for 1 epoch {:.2f} minutes".format(np.mean(times) / 60))
# Out:
# Epoch 9
# Max F1-score: 48.6756%
# ROC-AUC: 81.6868%
# Precision: 0.7742
# Recall: 0.3561
# Mean time for 1 epoch 15.19 minutes

# %% [markdown]
# ## Эксперимент BatchNorm

# %%
set_random_seed(42)
torch.cuda.empty_cache()

model = DeepCNNBatchNorm()
model = model.cuda()

opt = torch.optim.Adam(model.parameters(), lr=10**-4, weight_decay=10**-4)

val_auc_log, val_pr_log, val_rec_log, val_f1_log, val_acc_log, val_loss_log, times = train(model, opt, 10)
# Out:
# Time:  15.48718084494273
# Epoch 10: ROC-AUC = 80.54%
# Epoch 10: Precision = 0.785
# Epoch 10: Recall = 0.3
# Epoch 10: F1-score = 0.432
# Final ROC-AUC = 80.54%
# Final Precision = 0.785
# Final Recall = 0.3
# Final F1-score = 0.432

# %%
print("Epoch {}".format(np.argmax(val_f1_log)))
print("Max F1-score: {:.4f}%".format(val_f1_log[np.argmax(val_f1_log)]*100))
print("ROC-AUC: {:.4f}%".format(val_auc_log[np.argmax(val_f1_log)]*100))
print("Precision: {:.4f}".format(val_pr_log[np.argmax(val_f1_log)]))
print("Recall: {:.4f}".format(val_rec_log[np.argmax(val_f1_log)]))

print("Mean time for 1 epoch {:.2f} minutes".format(np.mean(times) / 60))
# Out:
# Epoch 7
# Max F1-score: 47.2185%
# ROC-AUC: 80.0917%
# Precision: 0.7465
# Recall: 0.3472
# Mean time for 1 epoch 15.45 minutes

# %% [markdown]
# ## Эксперимент InstanceNorm

# %%
set_random_seed(42)
torch.cuda.empty_cache()

model = DeepCNNInstanceNorm()
model = model.cuda()

opt = torch.optim.Adam(model.parameters(), lr=10**-4, weight_decay=10**-4)

val_auc_log, val_pr_log, val_rec_log, val_f1_log, val_acc_log, val_loss_log, times = train(model, opt, 10)
# Out:
# Time:  20.990138943990072
# Epoch 10: ROC-AUC = 81.00%
# Epoch 10: Precision = 0.771
# Epoch 10: Recall = 0.323
# Epoch 10: F1-score = 0.453
# Final ROC-AUC = 81.0%
# Final Precision = 0.771
# Final Recall = 0.323
# Final F1-score = 0.453

# %%
print("Epoch {}".format(np.argmax(val_f1_log)))
print("Max F1-score: {:.4f}%".format(val_f1_log[np.argmax(val_f1_log)]*100))
print("ROC-AUC: {:.4f}%".format(val_auc_log[np.argmax(val_f1_log)]*100))
print("Precision: {:.4f}".format(val_pr_log[np.argmax(val_f1_log)]))
print("Recall: {:.4f}".format(val_rec_log[np.argmax(val_f1_log)]))

print("Mean time for 1 epoch {:.2f} minutes".format(np.mean(times) / 60))
# Out:
# Epoch 7
# Max F1-score: 47.4270%
# ROC-AUC: 80.5818%
# Precision: 0.7376
# Recall: 0.3515
# Mean time for 1 epoch 18.59 minutes

# %% [markdown]
# # Эксперименты с количеством слоев

# %% [markdown]
# ## 7 слоев

# %%
class DeepCNNLayerNorm_v2(nn.Module):
    def __init__(self):
        super().__init__()
        self.seq = nn.Sequential(
            
            nn.Conv2d(1, 3, kernel_size=(3, 3), padding=1),
            nn.LayerNorm([3, 100, 1950]),
            nn.ReLU(),
            
            nn.Conv2d(3, 5, kernel_size=(3, 3), padding=1),
            nn.LayerNorm([5, 100, 1950]),
            nn.ReLU(),
            
            
            nn.Conv2d(5, 7, kernel_size=(3, 3), padding=1),
            nn.LayerNorm([7, 100, 1950]),
            nn.ReLU(),
            
            
            nn.Conv2d(7, 7, kernel_size=(3, 3), padding=1),
            nn.ReLU(),
            
            nn.Conv2d(7, 5, kernel_size=(3, 3), padding=1),
            nn.LayerNorm([5, 100, 1950]),
            nn.ReLU(),
            
            nn.Conv2d(5, 3, kernel_size=(3, 3), padding=1),
            nn.LayerNorm([3, 100, 1950]),
            nn.ReLU(),
            
            nn.Conv2d(3, 1, kernel_size=(3, 3), padding=1),
            nn.LayerNorm([1, 100, 1950]), 
            nn.ReLU(),
            
            nn.Dropout(0.25),
            
            nn.Linear(1950, 500),
            nn.Dropout(0.25),
            nn.ReLU(),
            
            nn.Linear(500, 2)
        )

    def forward(self, x):
        batch = x.shape[0]
        x = x.reshape(batch, 1, width, 1950)
        x = self.seq(x)
        x = torch.squeeze(x)
        x = F.log_softmax(x, dim=-1)
        return x

# %%
set_random_seed(42)
torch.cuda.empty_cache()

model = DeepCNNLayerNorm_v2()
model = model.cuda()

opt = torch.optim.Adam(model.parameters(), lr=10**-4, weight_decay=10**-4)

val_auc_log, val_pr_log, val_rec_log, val_f1_log, val_acc_log, val_loss_log, times = train(model, opt, 10)
# Out:
# Time:  37.88618706464767
# Epoch 1: ROC-AUC = 87.21%
# Epoch 1: Precision = 0.78
# Epoch 1: Recall = 0.441
# Epoch 1: F1-score = 0.562
# Epoch 2 of 10
# /home/alapteva/local/python3.9.0/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
print("Epoch {}".format(np.argmax(val_f1_log)))
print("Max F1-score: {:.4f}%".format(val_f1_log[np.argmax(val_f1_log)]*100))
print("ROC-AUC: {:.4f}%".format(val_auc_log[np.argmax(val_f1_log)]*100))
print("Precision: {:.4f}".format(val_pr_log[np.argmax(val_f1_log)]))
print("Recall: {:.4f}".format(val_rec_log[np.argmax(val_f1_log)]))

print("Mean time for 1 epoch {:.2f} minutes".format(np.mean(times) / 60))

# %% [markdown]
# ## 13 слоев

# %%
class DeepCNNLayerNorm_v3(nn.Module):
    def __init__(self):
        super().__init__()
        self.seq = nn.Sequential(
            
            nn.Conv2d(1, 3, kernel_size=(3, 3), padding=1),
            nn.LayerNorm([3, 100, 1950]),
            nn.ReLU(),
            
            nn.Conv2d(3, 5, kernel_size=(3, 3), padding=1),
            nn.LayerNorm([5, 100, 1950]),
            nn.ReLU(),
            
            
            nn.Conv2d(5, 7, kernel_size=(3, 3), padding=1),
            nn.LayerNorm([7, 100, 1950]),
            nn.ReLU(),
            
            
            nn.Conv2d(7, 9, kernel_size=(3, 3), padding=1),
            nn.LayerNorm([9, 100, 1950]),
            nn.ReLU(),
            
            
            nn.Conv2d(9, 11, kernel_size=(3, 3), padding=1),
            nn.LayerNorm([11, 100, 1950]),
            nn.ReLU(),
            
            nn.Conv2d(11, 13, kernel_size=(3, 3), padding=1),
            nn.LayerNorm([13, 100, 1950]),
            nn.ReLU(),
            
            nn.Conv2d(13, 13, kernel_size=(3, 3), padding=1),
            nn.ReLU(),
            
            nn.Conv2d(13, 11, kernel_size=(3, 3), padding=1),
            nn.LayerNorm([11, 100, 1950]),
            nn.ReLU(),
            
            nn.Conv2d(11, 9, kernel_size=(3, 3), padding=1),
            nn.LayerNorm([9, 100, 1950]),
            nn.ReLU(),
            
            nn.Conv2d(9, 7, kernel_size=(3, 3), padding=1),
            nn.LayerNorm([7, 100, 1950]),
            nn.ReLU(),
            
            nn.Conv2d(7, 5, kernel_size=(3, 3), padding=1),
            nn.LayerNorm([5, 100, 1950]),
            nn.ReLU(),
            
            nn.Conv2d(5, 3, kernel_size=(3, 3), padding=1),
            nn.LayerNorm([3, 100, 1950]),
            nn.ReLU(),
            
            nn.Conv2d(3, 1, kernel_size=(3, 3), padding=1),
            nn.LayerNorm([1, 100, 1950]),  # Укажите размеры после свертки
            nn.ReLU(),
            
            
            nn.Dropout(0.25),
            
            nn.Linear(1950, 500),
            nn.Dropout(0.25),
            nn.ReLU(),
            
            nn.Linear(500, 2)
        )

    def forward(self, x):
        batch = x.shape[0]
        x = x.reshape(batch, 1, width, 1950)
        x = self.seq(x)
        x = torch.squeeze(x)
        x = F.log_softmax(x, dim=-1)
        return x

# %%
set_random_seed(42)
torch.cuda.empty_cache()

model = DeepCNNLayerNorm_v3()
model = model.cuda()

opt = torch.optim.Adam(model.parameters(), lr=10**-4, weight_decay=10**-4)

val_auc_log, val_pr_log, val_rec_log, val_f1_log, val_acc_log, val_loss_log, times = train(model, opt, 10)

# %%
print("Epoch {}".format(np.argmax(val_f1_log)))
print("Max F1-score: {:.4f}%".format(val_f1_log[np.argmax(val_f1_log)]*100))
print("ROC-AUC: {:.4f}%".format(val_auc_log[np.argmax(val_f1_log)]*100))
print("Precision: {:.4f}".format(val_pr_log[np.argmax(val_f1_log)]))
print("Recall: {:.4f}".format(val_rec_log[np.argmax(val_f1_log)]))

print("Mean time for 1 epoch {:.2f} minutes".format(np.mean(times) / 60))

# %% [markdown]
# ## 21 слоев

# %%
class DeepCNNLayerNorm_v4(nn.Module):
    def __init__(self):
        super().__init__()
        self.seq = nn.Sequential(
            
            nn.Conv2d(1, 3, kernel_size=(3, 3), padding=1),
            nn.LayerNorm([3, 100, 1950]),
            nn.ReLU(),
            
            nn.Conv2d(3, 5, kernel_size=(3, 3), padding=1),
            nn.LayerNorm([5, 100, 1950]),
            nn.ReLU(),
            
            
            nn.Conv2d(5, 7, kernel_size=(3, 3), padding=1),
            nn.LayerNorm([7, 100, 1950]),
            nn.ReLU(),
            
            
            nn.Conv2d(7, 9, kernel_size=(3, 3), padding=1),
            nn.LayerNorm([9, 100, 1950]),
            nn.ReLU(),
            
            
            nn.Conv2d(9, 11, kernel_size=(3, 3), padding=1),
            nn.LayerNorm([11, 100, 1950]),
            nn.ReLU(),
            
            nn.Conv2d(11, 13, kernel_size=(3, 3), padding=1),
            nn.LayerNorm([13, 100, 1950]),
            nn.ReLU(),
            
            nn.Conv2d(13, 15, kernel_size=(3, 3), padding=1),
            nn.LayerNorm([15, 100, 1950]),
            nn.ReLU(),
            
            nn.Conv2d(15, 17, kernel_size=(3, 3), padding=1),
            nn.LayerNorm([17, 100, 1950]),
            nn.ReLU(),
            
            nn.Conv2d(17, 19, kernel_size=(3, 3), padding=1),
            nn.LayerNorm([19, 100, 1950]),
            nn.ReLU(),
            
            nn.Conv2d(19, 21, kernel_size=(3, 3), padding=1),
            nn.LayerNorm([21, 100, 1950]),
            nn.ReLU(),
            
            
            nn.Conv2d(21, 21, kernel_size=(3, 3), padding=1),
            nn.ReLU(),
            
            nn.Conv2d(21, 19, kernel_size=(3, 3), padding=1),
            nn.LayerNorm([19, 100, 1950]),
            nn.ReLU(),
            
            nn.Conv2d(19, 17, kernel_size=(3, 3), padding=1),
            nn.LayerNorm([17, 100, 1950]),
            nn.ReLU(),
            
            nn.Conv2d(17, 15, kernel_size=(3, 3), padding=1),
            nn.LayerNorm([15, 100, 1950]),
            nn.ReLU(),
            
            nn.Conv2d(15, 13, kernel_size=(3, 3), padding=1),
            nn.LayerNorm([13, 100, 1950]),
            nn.ReLU(),
            
            nn.Conv2d(13, 11, kernel_size=(3, 3), padding=1),
            nn.LayerNorm([11, 100, 1950]),
            nn.ReLU(),
            
            nn.Conv2d(11, 9, kernel_size=(3, 3), padding=1),
            nn.LayerNorm([9, 100, 1950]),
            nn.ReLU(),
            
            nn.Conv2d(9, 7, kernel_size=(3, 3), padding=1),
            nn.LayerNorm([7, 100, 1950]),
            nn.ReLU(),
            
            nn.Conv2d(7, 5, kernel_size=(3, 3), padding=1),
            nn.LayerNorm([5, 100, 1950]),
            nn.ReLU(),
            
            nn.Conv2d(5, 3, kernel_size=(3, 3), padding=1),
            nn.LayerNorm([3, 100, 1950]),
            nn.ReLU(),
            
            nn.Conv2d(3, 1, kernel_size=(3, 3), padding=1),
            nn.LayerNorm([1, 100, 1950]),  # Укажите размеры после свертки
            nn.ReLU(),
            
            
            nn.Dropout(0.25),
            
            nn.Linear(1950, 500),
            nn.Dropout(0.25),
            nn.ReLU(),
            
            nn.Linear(500, 2)
        )

    def forward(self, x):
        batch = x.shape[0]
        x = x.reshape(batch, 1, width, 1950)
        x = self.seq(x)
        x = torch.squeeze(x)
        x = F.log_softmax(x, dim=-1)
        return x

# %%
set_random_seed(42)
torch.cuda.empty_cache()

model = DeepCNNLayerNorm_v4()
model = model.cuda()

opt = torch.optim.Adam(model.parameters(), lr=10**-4, weight_decay=10**-4)

val_auc_log, val_pr_log, val_rec_log, val_f1_log, val_acc_log, val_loss_log, times = train(model, opt, 10)

# %%
print("Epoch {}".format(np.argmax(val_f1_log)))
print("Max F1-score: {:.4f}%".format(val_f1_log[np.argmax(val_f1_log)]*100))
print("ROC-AUC: {:.4f}%".format(val_auc_log[np.argmax(val_f1_log)]*100))
print("Precision: {:.4f}".format(val_pr_log[np.argmax(val_f1_log)]))
print("Recall: {:.4f}".format(val_rec_log[np.argmax(val_f1_log)]))

print("Mean time for 1 epoch {:.2f} minutes".format(np.mean(times) / 60))
